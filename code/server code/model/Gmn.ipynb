# %%
import numpy as np

# %%
#G(M, N) calculation

def G(M, N, Lambda, Miu):
    '''
    M: number of servers in the network
    N: number of jobs in the network
    Lambda: vector of arrival rate at each server
    Miu: vector of service rate at each server
    '''
    
    if N == 0:
        return 1
    elif M == 1:
        return Lambda[0]**N / Miu[0]
    else:
        return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
    
if __name__ == '__main__':
    np.random.seed(2)
    M = 20
    N = 500
    Lambda = np.random.randn(M)
    Miu = np.random.randn(M)    
    # %time a = G(M, N, Lambda, Miu)
    # %time b = G(M-1, N, Lambda, Miu)
    a/b
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# ...
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# <ipython-input-4-4b75e2c4f067> in G(M, N, Lambda, Miu)
#      14         return Lambda[0]**N / Miu[0]
#      15     else:
# ---> 16         return Lambda[M-1]/Miu[M-1] * G(M, N-1, Lambda, Miu) + G(M-1, N, Lambda, Miu)
#      17
#      18 if __name__ == '__main__':
#
# KeyboardInterrupt:
