# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# to be done
# compare the cen and dis in one graph

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate', 'BP', 'RC', 'DP']
def draw(add, title):
    dfLst = []
    for _add in add:
        _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
        for df in _dfLst:
            df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
        dfLst.append(_dfLst)
    n = int(df.shape[0]/4)
    f, ax = plt.subplots(4,1,figsize=(6,24), sharex=True)
    #plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(4):
        for n,df in enumerate(dfLst):
            df0, df1 = df
            if n<4:
                residual, color = 7, ['r','r']
            else: 
                residual, color = 4, ['b','b']
            re0 = df0[df0.index%residual==i]
            re1 = df1[df1.index%residual==i]
            #ax[i].plot(re1.para, re1.mu, color[0])
            ax[i].fill_between(re0.para, re0.high, re0.low, alpha=0.2, color=color[1])
            marker = ['-', '--', '-.', ':','-', '--', '-.', ':']
            ax[i].plot(re0.para, re0.mu, color[1], linestyle=marker[n])
            if i == 0: ax[i].legend(['Instance'+str(_) for _ in list(range(1,5))*2])
            ax[i].set_ylabel(indicators[i])
            if i in [0,1]:
                ax[i].set(ylim=(-1,7))
            else:
                ax[i].set(ylim=(0,1.1))
        #ax[i].legend()
    f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/中文论文/graph/sim/'\
             +title.replace(' ', '')+'_compare.png', dpi = 150, bbox_inches='tight')

def addLst(add1, add2):
    # lst = [add1+'V'+str(x)+add2 for x in range(4)]
    # lst = [[add1+'simulation'+add2, add1+'ODE'+add2]]
    lst = []
    for x in range(8):
        if x <4: 
            lst.append([add1+str(x)+'/central/simulation'+add2, add1+str(x)+'/central/ODE'+add2])
        else:
            lst.append([add1+str(x-4)+'/dis/simulation'+add2, add1+str(x-4)+'/dis/ODE'+add2])
    return lst
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V'
add2 = '/Beta/varyBeta.csv'
addLst(add1, add2)
# Out:
# [['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V0/central/simulation/Beta/varyBeta.csv',
#   '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V0/central/ODE/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/central/simulation/Beta/varyBeta.csv',
#   '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/central/ODE/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V2/central/simulation/Beta/varyBeta.csv',
#   '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V2/central/ODE/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/simulation/Beta/varyBeta.csv',
#   '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/ODE/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V0/dis/simulation/Beta/varyBeta.csv',
# ...

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate', 'BP', 'RC', 'DP']
def draw(add, title):
    dfLst = []
    for _add in add:
        _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
        for df in _dfLst:
            df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
        dfLst.append(_dfLst)
    n = int(df.shape[0]/4)
    f, ax = plt.subplots(4,1,figsize=(6,24), sharex=True)
    #plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(4):
        for n,df in enumerate(dfLst):
            df0= df[0]
            if n<4:
                residual, color = 7, ['b','r']
            else: 
                residual, color = 4, ['g','b']
            re0 = df0[df0.index%residual==i]
            #re1 = df1[df1.index%residual==i]
            #ax[i].plot(re1.para, re1.mu, color[0])
            #ax[i].plot(re1.para, re1.mu, color[0])
            ax[i].fill_between(re0.para, re0.high, re0.low, alpha=0.2, color=color[1])
            marker = ['-', '--', '-.', ':','-', '--', '-.', ':']
            ax[i].plot(re0.para, re0.mu, color[1], linestyle=marker[n])
            if i == 0: ax[i].legend(['Instance'+str(_) for _ in list(range(1,5))*2])
            ax[i].set_ylabel(indicators[i])
#             if i in [0,1]:
#                 ax[i].set(ylim=(-1,7))
#             else:
#                 ax[i].set(ylim=(0,1.0))
        #ax[i].legend()
    f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/中文论文/graph/sim/'\
             +title.replace(' ', '')+'_A4M80compare.png', dpi = 150, bbox_inches='tight')
    
def addLst(add1, add2):
    # lst = [add1+'V'+str(x)+add2 for x in range(4)]
    # lst = [[add1+'simulation'+add2, add1+'ODE'+add2]]
    lst = []
    for x in range(8):
        if x <4: 
            lst.append([add1+str(x)+'/central/simulation'+add2])
        else:
            lst.append([add1+str(x-4)+'/dis/simulation'+add2])
    return lst
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V'
add2 = '/Beta/varyBeta.csv'
addLst(add1, add2)
# Out:
# [['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V0/central/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/central/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V2/central/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V0/dis/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/dis/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V2/dis/simulation/Beta/varyBeta.csv'],
#  ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/dis/simulation/Beta/varyBeta.csv']]

# %%
# Beta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V'
add2 = '/Beta/varyBeta.csv'
title = 'Vary Beta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Beta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/'
add2 = '/Beta/varyBeta.csv'
title = 'Vary Beta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Gamma
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V'
add2 = '/Gamma/varyGamma.csv'
title = 'Vary Gamma'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-b9fab436a3ac> in <module>
#       3 add2 = '/Gamma/varyGamma.csv'
#       4 title = 'Vary Gamma'
# ----> 5 draw(addLst(add1, add2), title)
#       6 #         exp_dir = 'Plot/'
#       7 #         if not os.path.exists(exp_dir):
#
# <ipython-input-2-89e4c5664588> in draw(add, title)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
#       7             df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
#
# <ipython-input-2-89e4c5664588> in <listcomp>(.0)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
# ...

# %%
# Delta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V'
add2 = '/Delta/varyDelta.csv'
title = 'Vary Delta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-bb999bada3cc> in <module>
#       3 add2 = '/Delta/varyDelta.csv'
#       4 title = 'Vary Delta'
# ----> 5 draw(addLst(add1, add2), title)
#       6 #         exp_dir = 'Plot/'
#       7 #         if not os.path.exists(exp_dir):
#
# <ipython-input-53-65d4a324bdcd> in draw(add, title)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
#       7             df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
#
# <ipython-input-53-65d4a324bdcd> in <listcomp>(.0)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
# ...

# %%
# Mu
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V'
add2 = '/Mu/varyMu.csv'
title = 'Vary Mu'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# B_
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/'
add2 = '/B_/varyB_.csv'
title = 'Vary B_'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# N
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V'
add2 = '/N/varyN.csv'
title = 'Vary N'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# D_
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V3/central/'
add2 = '/D_/varyD_.csv'
title = 'Vary D_'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate']
def draw(add, title):
    dfLst = []
    for _add in add:
        _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
        for df in _dfLst:
            df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
        dfLst.append(_dfLst)
    n = int(df.shape[0]/4)
    f, ax = plt.subplots(4,1,figsize=(5,16), sharex=True)
    plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(4):
        for df in dfLst:
            df0, df1 = df
            re0 = df0[df0.index%4==i]
            re1 = df1[df1.index%4==i]
            ax[i].plot(re1.para, re1.mu,'b')
            ax[i].fill_between(re0.para, re0.high, re0.low, alpha=0.1, color='r')
            ax[i].plot(re0.para, re0.mu, 'r', linestyle='dashed')
            ax[i].set_ylabel(indicators[i])
        #ax[i].legend()
#     f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/article review/My paper/modelAnalysis/graph/central//A50Cen'\
#              +title.replace(' ', '')+'V1.png', dpi = 150, bbox_inches='tight')

# %%
# Beta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/dis/'
add2 = '/Beta/varyBeta.csv'
title = 'Vary Beta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-113c2bc2f389> in <module>
#       3 add2 = '/Beta/varyBeta.csv'
#       4 title = 'Vary Beta'
# ----> 5 draw(addLst(add1, add2), title)
#       6 #         exp_dir = 'Plot/'
#       7 #         if not os.path.exists(exp_dir):
#
# <ipython-input-18-c2cc0eb8e75e> in draw(add, title)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
#       7             df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
#
# <ipython-input-18-c2cc0eb8e75e> in <listcomp>(.0)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
# ...

# %%
# Theta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/dis/'
add2 = '/Theta/varyTheta.csv'
title = 'Vary Theta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# N
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6V1/dis/'
add2 = '/N/varyN.csv'
title = 'Vary N'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Mu
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/double/V'
add2 = '/dis/Mu/varyMu.csv'
title = 'Vary Mu'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-baddff7ed861> in <module>
#       3 add2 = '/dis/Mu/varyMu.csv'
#       4 title = 'Vary Mu'
# ----> 5 draw(addLst(add1, add2), title)
#       6 #         exp_dir = 'Plot/'
#       7 #         if not os.path.exists(exp_dir):
#
# <ipython-input-58-c2cc0eb8e75e> in draw(add, title)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
#       7             df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
#
# <ipython-input-58-c2cc0eb8e75e> in <listcomp>(.0)
#       3     dfLst = []
#       4     for _add in add:
# ----> 5         _dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in _add]
#       6         for df in _dfLst:
# ...

# %%
# cen parameters
import numpy as np
# set parameters
# set the parameters
# get the number of states S
'''
A: number of areas
M: number of total bikes
S: number of total states
Pij: transfering possibility matrix
Beta: broken rate
ArrMtx: arrival rates of each area
Gamma: gathering rate
Mu: fix rate
Delta: distributing rate
RhoMtx: matrix of ride rates
N: number of fix servers
B_: valve value at broken pool
D_: valve value at distributing pool
'''
Instance = 0
FileAdd = 'C:\\Rebalancing\\nowModel\\result\\A2M6V'+str(Instance)+'\\simulation\\'

np.random.seed(Instance)
A = 2
M = 6

def getPij(a):
    temp = np.random.rand(A,A)
    return (temp/sum(temp)).T
Pij = getPij(A)
ArrLst = np.random.rand(A)
Beta = 0.3
RhoMtx = [[1.0] * A for i in range(A)]
#RhoMtx = np.random.rand(A, A)

Gamma = 1.0
Mu = 1.0
N = 1
Delta = 1.0
B_, D_ = 2, 2

# A = 2
# M = 6
# def getPij(a):
#     temp = np.random.rand(A,A)
#     return (temp/sum(temp)).T
# Pij = getPij(A)
# # Pij = [[0.3, 0.7],
# #        [0.7, 0.3]]
# # Pij = [[0.1, 0.2, 0.3, 0.4],
# #        [0.2, 0.3, 0.4, 0.1],
# #        [0.3, 0.4, 0.1, 0.2],
# #        [0.4, 0.3, 0.2, 0.1]]
# Beta = 0.3
# ArrLst = [5.0, 5.0]
# #ArrLst = [5.0, 5.0, 6.0, 7.0]
# Gamma = 1.0
# Mu = 1.0
# Delta = 1.0
# # RhoMtx = [[1.0, 1.0], 
# #           [1.0, 1.0]]
# RhoMtx = [[1.0] * A for i in range(A)]
# N = 1
# B_, D_ = 2, 2

# %%
# dis parameters
import numpy as np
# set parameters
# set the parameters
# get the number of states S
'''
A: number of areas
M: number of total bikes
S: number of total states
Pij: transfering possibility matrix
Beta: broken rate
ArrMtx: arrival rates of each area
Gamma: gathering rate
Mu: fix rate
Delta: distributing rate
RhoMtx: matrix of ride rates
N: number of fix servers
B_: valve value at broken pool
D_: valve value at distributing pool
'''
Instance = 0
FileAdd = 'C:\\Rebalancing\\nowModel\\result\\A2M6\\V'+str(Instance)+'\\ODE\\'
np.random.seed(Instance)
A = 2
M = 6

def getPij(a):
    temp = np.random.rand(A,A)
    return (temp/sum(temp)).T
Pij = getPij(A)
ArrLst = np.random.rand(A)
Beta = 0.3
RhoMtx = [[1.0] * A for i in range(A)]
# RhoMtx = np.random.rand(A, A)

Theta = 1.0
Mu =1.0
N = 1
# A = 2
# M = 6
# def getPij(a):
#     temp = np.random.rand(A,A)
#     return (temp/sum(temp)).T
# Pij = getPij(A)
# # Pij = [[0.3, 0.7],
# #        [0.7, 0.3]]
# # Pij = [[0.1, 0.2, 0.3, 0.4],
# #        [0.2, 0.3, 0.4, 0.1],
# #        [0.3, 0.4, 0.1, 0.2],
# #        [0.4, 0.3, 0.2, 0.1]]
# Beta = 0.3
#ArrLst = [5.0, 5.0]
# #ArrLst = [5.0, 5.0, 6.0, 7.0]
# Gamma = 1.0
# Mu = 1.0
# Delta = 1.0
# # RhoMtx = [[1.0, 1.0], 
# #           [1.0, 1.0]]
# RhoMtx = [[1.0] * A for i in range(A)]
# N = 1
# B_, D_ = 2, 2
