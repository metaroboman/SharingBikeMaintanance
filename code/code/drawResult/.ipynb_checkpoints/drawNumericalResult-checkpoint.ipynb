# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/valarian/SJTU/SJTU/毕业论文/Data/code/simulation'+\
                 '/nowModel/testCode/testGetPerformance.csv', names = ['a', 'b'])
plt.plot(df.a, df.b)
plt.xlabel('time')
plt.ylabel('Average normal bikes')
#plt.show()

plt.savefig('/Users/valarian/SJTU/SJTU/毕业论文/Data/code/simulation'+\
                 '/nowModel/testCode/centralAvgNormal-time.png', dpi=150)

# %%
def addLst(add1, add2):
    # lst = [add1+'V'+str(x)+add2 for x in range(4)]
    lst = [add1 + add2]
    return lst
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6'
add2 = '/central/ODE/Beta/varyBeta.csv'
addLst(add1, add2)
# Out:
# ['/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A2M6/central/ODE/Beta/varyBeta.csv']

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate', 'BP', 'RC', 'DP']
def draw(add, title):
    dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in add]
    for df in dfLst:
        df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
    n = int(df.shape[0]/7)
    f, ax = plt.subplots(7,1,figsize=(7,28), sharex=True)
    plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(7):
        for df in dfLst:
            re = df[df.index%7==i]
            ax[i].plot(re.para, re.mu)
            ax[i].fill_between(re.para, re.high, re.low, alpha=0.1, color='r')
            ax[i].set_ylabel(indicators[i])
        #ax[i].legend()
#     f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/article review/My paper/modelAnalysis/graph/central//A50Cen'\
#              +title.replace(' ', '')+'V1.png', dpi = 150, bbox_inches='tight')

# %%
# B_
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/B_/varyB_.csv'
title = 'Vary B_'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Beta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/Beta/varyBeta.csv'
title = 'Vary Beta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# D_
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/D_/varyD_.csv'
title = 'Vary D_'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Delta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/Delta/varyDelta.csv'
title = 'Vary Delta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Gamma
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/Gamma/varyGamma.csv'
title = 'Vary Gamma'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Mu
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/Mu/varyMu.csv'
title = 'Vary Mu'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# N
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/central/simulation/N/varyN.csv'
title = 'Vary N'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate']
def draw(add, title):
    df = pd.read_csv(add, names=('para', 'mu', 'sig'))
    df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
    n = int(df.shape[0]/4)
    f, ax = plt.subplots(4,1,figsize=(5,16), sharex=True)
    plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(4):
        re = df[df.index%4==i]
        ax[i].plot(re.para, re.mu)
        ax[i].fill_between(re.para, re.high, re.low, alpha=0.1)
        ax[i].set_ylabel(indicators[i])
        #ax[i].legend()
    f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/article review/My paper/modelAnalysis/graph/dis'\
             +title.replace(' ', '')+'.png', dpi = 150, bbox_inches='tight')

# %%
# N
add = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicatorsA2M6_2020_2_27/'+\
    'distributed/A2M6N/varyN.csv'
title = 'Vary N'
draw(add, title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-bc3e3c93b30b> in <module>
#       3     'distributed/A2M6N/varyN.csv'
#       4 title = 'Vary N'
# ----> 5 draw(add, title)
#       6 #         exp_dir = 'Plot/'
#       7 #         if not os.path.exists(exp_dir):
#
# <ipython-input-51-078e81265ab7> in draw(add, title)
#       1 indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate']
#       2 def draw(add, title):
# ----> 3     df = pd.read_csv(add, names=('para', 'mu', 'sig'))
#       4     df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
#       5     n = int(df.shape[0]/4)
#
# ~/python/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/python/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/python/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/python/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/python/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/valarian/SJTU/SJTU/\xe6\xaf\x95\xe4\xb8\x9a\xe8\xae\xba\xe6\x96\x87/Data/result/PerfIndicatorsA2M6_2020_2_27/distributed/A2M6N/varyN.csv' does not exist: b'/Users/valarian/SJTU/SJTU/\xe6\xaf\x95\xe4\xb8\x9a\xe8\xae\xba\xe6\x96\x87/Data/result/PerfIndicatorsA2M6_2020_2_27/distributed/A2M6N/varyN.csv'

# %%
# Theta
add = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicatorsA2M6_2020_2_27/'+\
    'distributed/A2M6Theta/varyTheta.csv'
title = 'Vary Theta'
draw(add, title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Mu
add = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicatorsA2M6_2020_2_27/'+\
    'distributed/A2M6Mu/varyMu.csv'
title = 'Vary Mu'
draw(add, title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Beta
add = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicatorsA2M6_2020_2_27/'+\
    'distributed/A2M6Beta/varyBeta.csv'
title = 'Vary Beta'
draw(add, title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
indicators = ['Normal bikes', 'Broken bikes', 'Lost rate', 'Idle rate']
def draw(add, title):
    dfLst = [pd.read_csv(a, names=('para', 'mu', 'sig')) for a in add]
    for df in dfLst:
        df['low'], df['high'] = df['mu'] - 1.96*df['sig'], df['mu'] + 1.96*df['sig']
    n = int(df.shape[0]/4)
    f, ax = plt.subplots(4,1,figsize=(5,16), sharex=True)
    plt.xlabel('Value')
    #ax[0].set_title(title)
    
    for i in range(4):
        for df in dfLst:
            re = df[df.index%4==i]
            ax[i].plot(re.para, re.mu)
            ax[i].fill_between(re.para, re.high, re.low, alpha=0.1, color='r')
            ax[i].set_ylabel(indicators[i])
        #ax[i].legend()
#     f.savefig('/Users/valarian/SJTU/SJTU/毕业论文/article review/My paper/modelAnalysis/graph/A50Dis'\
#              +title.replace(' ', '')+'V1.png', dpi = 150, bbox_inches='tight')

# %%
# N
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/dis/simulation/N/varyN.csv'
title = 'Vary N'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Theta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/dis/simulation/Theta/varyTheta.csv'
title = 'Vary Theta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Mu
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/dis/simulation/Mu/varyMu.csv'
title = 'Vary Mu'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)

# %%
# Beta
add1 = '/Users/valarian/SJTU/SJTU/毕业论文/Data/result/PerfIndicators/A4M80/V0'
add2 = '/dis/simulation/Beta/varyBeta.csv'
title = 'Vary Beta'
draw(addLst(add1, add2), title)
#         exp_dir = 'Plot/'
#         if not os.path.exists(exp_dir):
#             os.makedirs(exp_dir, exist_ok=True)
#         f.savefig(os.path.join('Plot', 'avgreward' + '.png'), dpi=50)
